# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhilsimha31/climatescope-project/blob/feature%2Fdata-exploration/Climate_scope.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***ClimateScope:Visualizing Global Weather Trends and Extreme Events***
# ***
# Project objective
# The objective of ClimateScope is to analyze and visually represent global weather patterns using the Global Weather Repository dataset. This project aims to uncover seasonal trends, regional variations, and extreme weather events through interactive and insightful visualizations. By leveraging daily-updated, worldwide weather data, the project will enable users to explore climate behavior over time, compare conditions across regions, and identify anomalies. The ultimate goal is to provide an accessible, data-driven platform that supports climate awareness, decision-making, and further research into global weather dynamics.

# %%
#Download the Global Weather Repository dataset from Kaggle by using opendatasets
# !pip install opendatasets
# Out:
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from opendatasets) (4.67.1)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.12/dist-packages (from opendatasets) (1.7.4.5)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from opendatasets) (8.2.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (2025.8.3)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (3.4.3)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (3.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (5.29.5)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (2.32.4)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (1.3)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (2.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (0.5.1)
# Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Installing collected packages: opendatasets
# Successfully installed opendatasets-0.1.22

# %%
import opendatasets as od
od.download("https://www.kaggle.com/datasets/nelgiriyewithana/global-weather-repository/data")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: Nikhilsimha123
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/nelgiriyewithana/global-weather-repository
# Downloading global-weather-repository.zip to ./global-weather-repository
# 100%|██████████| 7.69M/7.69M [00:00<00:00, 807MB/s]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('/content/global-weather-repository/GlobalWeatherRepository.csv') #reading the file

# %% [markdown]
# ***To view total observation and colums present in data set***

# %%
df.shape # to see total observation and colums present in data set
# Out:
# (97045, 41)

# %%
pd.set_option('display.max_columns', 41) # to see all columns

# %%
df.head() # to see top 5 row's
# Out:
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1715849100  2024-05-16 13:15                 26.6
# 1          1715849100  2024-05-16 10:45                 19.0
# 2          1715849100  2024-05-16 09:45                 23.0
# 3          1715849100  2024-05-16 10:45                  6.3
# 4          1715849100  2024-05-16 09:45                 26.0
#
#    temperature_fahrenheit condition_text  wind_mph  wind_kph  wind_degree  \
# 0                    79.8  Partly Cloudy       8.3      13.3          338
# 1                    66.2  Partly cloudy       6.9      11.2          320
# 2                    73.4          Sunny       9.4      15.1          280
# 3                    43.3  Light drizzle       7.4      11.9          215
# 4                    78.8  Partly cloudy       8.1      13.0          150
#
#   wind_direction  pressure_mb  pressure_in  precip_mm  precip_in  humidity  \
# 0            NNW       1012.0        29.89        0.0       0.00        24
# 1             NW       1012.0        29.88        0.1       0.00        94
# 2              W       1011.0        29.85        0.0       0.00        29
# 3             SW       1007.0        29.75        0.3       0.01        61
# 4            SSE       1011.0        29.85        0.0       0.00        89
#
#    cloud  feels_like_celsius  feels_like_fahrenheit  visibility_km  \
# 0     30                25.3                   77.5           10.0
# 1     75                19.0                   66.2           10.0
# 2      0                24.6                   76.4           10.0
# 3    100                 3.8                   38.9            2.0
# 4     50                28.7                   83.6           10.0
#
#    visibility_miles  uv_index  gust_mph  gust_kph  \
# 0               6.0       7.0       9.5      15.3
# 1               6.0       5.0      11.4      18.4
# 2               6.0       5.0      13.9      22.3
# 3               1.0       2.0       8.5      13.7
# 4               6.0       8.0      12.5      20.2
#
#    air_quality_Carbon_Monoxide  air_quality_Ozone  \
# 0                        277.0              103.0
# 1                        193.6               97.3
# 2                        540.7               12.2
# 3                        170.2               64.4
# 4                       2964.0               19.0
#
#    air_quality_Nitrogen_dioxide  air_quality_Sulphur_dioxide  \
# 0                           1.1                          0.2
# 1                           0.9                          0.1
# 2                          65.1                         13.4
# 3                           1.6                          0.2
# 4                          72.7                         31.5
#
#    air_quality_PM2.5  air_quality_PM10  air_quality_us-epa-index  \
# 0                8.4              26.6                         1
# 1                1.1               2.0                         1
# 2               10.4              18.4                         1
# 3                0.7               0.9                         1
# 4              183.4             262.3                         5
#
#    air_quality_gb-defra-index   sunrise    sunset  moonrise   moonset  \
# 0                           1  04:50 AM  06:50 PM  12:12 PM  01:11 AM
# 1                           1  05:21 AM  07:54 PM  12:58 PM  02:14 AM
# 2                           1  05:40 AM  07:50 PM  01:15 PM  02:14 AM
# 3                           1  06:31 AM  09:11 PM  02:12 PM  03:31 AM
# 4                          10  06:12 AM  05:55 PM  01:17 PM  12:38 AM
#
#        moon_phase  moon_illumination
# 0  Waxing Gibbous                 55
# 1  Waxing Gibbous                 55
# 2  Waxing Gibbous                 55
# 3  Waxing Gibbous                 55
# 4  Waxing Gibbous                 55

# %%
df.tail()# to see bottom 5 row's
# Out:
#          country location_name  latitude  longitude         timezone  \
# 97040  Venezuela       Caracas   10.5000   -66.9167  America/Caracas
# 97041    Vietnam         Hanoi   21.0333   105.8500     Asia/Bangkok
# 97042      Yemen         Sanaa   15.3547    44.2067        Asia/Aden
# 97043     Zambia        Lusaka  -15.4167    28.2833    Africa/Lusaka
# 97044   Zimbabwe        Harare  -17.8178    31.0447    Africa/Harare
#
#        last_updated_epoch      last_updated  temperature_celsius  \
# 97040          1758960000  2025-09-27 04:00                 26.2
# 97041          1758959100  2025-09-27 14:45                 34.2
# 97042          1758959100  2025-09-27 10:45                 23.3
# 97043          1758959100  2025-09-27 09:45                 23.4
# 97044          1758959100  2025-09-27 09:45                 20.5
#
#        temperature_fahrenheit condition_text  wind_mph  wind_kph  wind_degree  \
# 97040                    79.2          Clear       4.0       6.5          180
# 97041                    93.6  Partly cloudy       4.0       6.5          322
# 97042                    74.0          Sunny      15.9      25.6           61
# 97043                    74.2          Sunny      13.0      20.9           74
# 97044                    69.0          Sunny       8.1      13.0           68
#
#       wind_direction  pressure_mb  pressure_in  precip_mm  precip_in  \
# 97040              S       1010.0        29.83       0.00       0.00
# 97041             NW       1010.0        29.83       0.65       0.03
# 97042            ENE       1015.0        29.96       0.00       0.00
# 97043            ENE       1018.0        30.05       0.00       0.00
# 97044            ENE       1020.0        30.13       0.00       0.00
#
#        humidity  cloud  feels_like_celsius  feels_like_fahrenheit  \
# 97040        89     25                29.0                   84.3
# 97041        56     50                45.2                  113.4
# 97042        20      0                22.8                   73.0
# 97043        45      7                24.8                   76.6
# 97044        56     25                20.5                   69.0
#
#        visibility_km  visibility_miles  uv_index  gust_mph  gust_kph  \
# 97040           10.0               6.0       0.0       8.5      13.6
# 97041           10.0               6.0       6.6       5.1       8.3
# 97042           10.0               6.0       8.4      18.3      29.4
# 97043           10.0               6.0       3.9      14.9      24.0
# 97044           10.0               6.0       4.9       9.3      14.9
#
#        air_quality_Carbon_Monoxide  air_quality_Ozone  \
# 97040                      1557.70               65.0
# 97041                      1045.25               34.0
# 97042                       299.70               77.0
# 97043                       358.90               81.0
# 97044                       569.80               89.0
#
#        air_quality_Nitrogen_dioxide  air_quality_Sulphur_dioxide  \
# 97040                        25.900                        6.475
# 97041                        36.630                       26.085
# 97042                         1.850                        4.625
# 97043                         1.295                        1.110
# 97044                         3.885                        0.925
#
#        air_quality_PM2.5  air_quality_PM10  air_quality_us-epa-index  \
# 97040             22.200            22.385                         2
# 97041             33.485            33.670                         2
# 97042             27.935            81.585                         2
# 97043             17.575            17.945                         2
# 97044             37.185            37.555                         2
#
#        air_quality_gb-defra-index   sunrise    sunset  moonrise   moonset  \
# 97040                           2  06:16 AM  06:20 PM  10:46 AM  10:25 PM
# 97041                           3  05:47 AM  05:48 PM  10:13 AM  09:07 PM
# 97042                           3  05:53 AM  05:56 PM  10:16 AM  09:35 PM
# 97043                           2  05:53 AM  06:03 PM  09:18 AM  10:48 PM
# 97044                           4  05:41 AM  05:53 PM  09:01 AM  10:42 PM
#
#             moon_phase  moon_illumination
# 97040  Waxing Crescent                 24
# 97041  Waxing Crescent                 21
# 97042  Waxing Crescent                 22
# 97043  Waxing Crescent                 22
# 97044  Waxing Crescent                 22

# %%
df.info()#Inspect dataset structure, data types, and key variable
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97045 entries, 0 to 97044
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       97045 non-null  object
#  1   location_name                 97045 non-null  object
#  2   latitude                      97045 non-null  float64
#  3   longitude                     97045 non-null  float64
#  4   timezone                      97045 non-null  object
#  5   last_updated_epoch            97045 non-null  int64
#  6   last_updated                  97045 non-null  object
#  7   temperature_celsius           97045 non-null  float64
#  8   temperature_fahrenheit        97045 non-null  float64
#  9   condition_text                97045 non-null  object
#  10  wind_mph                      97045 non-null  float64
#  11  wind_kph                      97045 non-null  float64
#  12  wind_degree                   97045 non-null  int64
#  13  wind_direction                97045 non-null  object
#  14  pressure_mb                   97045 non-null  float64
#  15  pressure_in                   97045 non-null  float64
#  16  precip_mm                     97045 non-null  float64
#  17  precip_in                     97045 non-null  float64
#  18  humidity                      97045 non-null  int64
#  19  cloud                         97045 non-null  int64
#  20  feels_like_celsius            97045 non-null  float64
#  21  feels_like_fahrenheit         97045 non-null  float64
#  22  visibility_km                 97045 non-null  float64
#  23  visibility_miles              97045 non-null  float64
#  24  uv_index                      97045 non-null  float64
#  25  gust_mph                      97045 non-null  float64
#  26  gust_kph                      97045 non-null  float64
#  27  air_quality_Carbon_Monoxide   97045 non-null  float64
#  28  air_quality_Ozone             97045 non-null  float64
#  29  air_quality_Nitrogen_dioxide  97045 non-null  float64
#  30  air_quality_Sulphur_dioxide   97045 non-null  float64
#  31  air_quality_PM2.5             97045 non-null  float64
#  32  air_quality_PM10              97045 non-null  float64
#  33  air_quality_us-epa-index      97045 non-null  int64
#  34  air_quality_gb-defra-index    97045 non-null  int64
#  35  sunrise                       97045 non-null  object
#  36  sunset                        97045 non-null  object
#  37  moonrise                      97045 non-null  object
#  38  moonset                       97045 non-null  object
#  39  moon_phase                    97045 non-null  object
#  40  moon_illumination             97045 non-null  int64
# dtypes: float64(23), int64(7), object(11)
# memory usage: 30.4+ MB
